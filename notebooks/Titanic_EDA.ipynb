# %% [markdown]
# # Titanic Dataset Exploratory Data Analysis (EDA)
#
# ## NeuroFive Solutions – Machine Learning Track
#
# ### Week 1 Project: Set Up Your Data Science Toolkit & Explore Your First Dataset
#
# **Author:** Zuhran Rasool
#
# **Tools & Libraries:** Python, Jupyter Notebook, Pandas, NumPy, Matplotlib, Seaborn
#
# **Dataset:** Titanic – Machine Learning from Disaster (Kaggle)
